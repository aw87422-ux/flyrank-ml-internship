# %% [markdown]
# <a href="https://colab.research.google.com/github/aw87422-ux/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# My Lane

I chose the Search Ranking lane because improving search results helps users find more relevant content. Better ranking improves the user experience and helps users find useful information faster.
# Out:
#   File "/tmp/ipykernel_414/2763825273.py", line 3
#     I chose the Search Ranking lane because improving search results helps users find more relevant content. Better ranking improves the user experience and helps users find useful information faster.
#       ^
# SyntaxError: invalid syntax

# %%
# Research Question

Decision:
Determine which content should rank higher for a user's search query.

Action:
Use the model to rank the most relevant pages at the top of the search results.

Cost of a Wrong Recommendation:
If irrelevant content is ranked too high, users may not find the information they need, reducing trust in the search system.

Why Machine Learning?
Machine learning can identify patterns in search data that are difficult to capture with manually written rules.
# Out:
#   File "/tmp/ipykernel_414/1927266025.py", line 4
#     Determine which content should rank higher for a user's search query.
#                                                          ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# Quick Look at the Data

From the starter dataset:

- Total rows: 30,000
- Total columns: 44
- The dataset contains structured search-related features such as search volume, competition level, content type, and word count.

These numbers show that the dataset is large enough to explore search ranking and identify useful patterns.
# Out:
#   File "/tmp/ipykernel_414/1882916271.py", line 3
#     From the starter dataset:
#          ^
# SyntaxError: invalid syntax

# %%
# Careful Words

This notebook proposes a research direction based on the available data. It does not prove that one ranking method is always better. Further experiments and evaluation will be required before drawing conclusions.

# %%
# Self Check

- ✓ Chose a project lane.
- ✓ Explained the decision and action.
- ✓ Included real numbers from the dataset.
- ✓ Used careful language without making unsupported claims.

# %%
print("Week 1 Research Question Completed")
# Out:
# Week 1 Research Question Completed
